# %%
import pandas as pd

# %%
hr = pd.read_csv('HR-Employee-Attrition.csv')

# %%
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
hr.shape
# Out:
# (1470, 35)

# %%
hr.duplicated().sum()
# Out:
# 0

# %%
hr.dropna()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import seaborn as sns

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
sns.countplot(x='Department',data =hr, hue='Attrition');

# %%
hr_numeric =hr.select_dtypes(include ='int64')

# %%
#Calculate the correlation matrix for the numeric values
corr_matrix = hr_numeric.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.title("Correlation Map for numeric Values")
# Out:
# Text(0.5, 1.0, 'Correlation Map for numeric Values')

# %% [markdown]
# # Finding Active Employees

# %%
#Finding Active Employees
hr.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
corr_matrix
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
# Active Emplpoyees:1233
#Attrition Count:237
#Attrition Rate of employee
(237/1470)*100
#16.12%
# Out:
# 16.122448979591837

# %%
#Finding the number of male and female employees and the attrition rate
hr.Gender.value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
hr.groupby(['Gender','Attrition']).size()
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# dtype: int64

# %%
print("Male attrition rate is :", (150/882)*100)
# Out:
# Male attrition rate is : 17.006802721088434

# %%
print("Female Attrition Rate is:",(87/588)*100)
# Out:
# Female Attrition Rate is: 14.795918367346939

# %%
hr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr.groupby(['JobSatisfaction','Attrition']).size()
# Out:
# JobSatisfaction  Attrition
# 1                No           223
#                  Yes           66
# 2                No           234
#                  Yes           46
# 3                No           369
#                  Yes           73
# 4                No           407
#                  Yes           52
# dtype: int64

# %%
columns =['JobSatisfaction','Gender','EnvironmentSatisfaction','JobInvolvement','PercentSalaryHike',
          'RelationshipSatisfaction','WorkLifeBalance','YearsSinceLastPromotion','EducationField','Age','DistanceFromHome','TrainingTimesLastYear']
for i in columns:
    plt.figure()
    plt.figure(figsize=(10,5))
    ax=sns.countplot(x=i, data =hr , hue ='Attrition');
    plt.bar_label(ax.containers[0])
    plt.bar_label(ax.containers[1])
    plt.show()

# %% [markdown]
# # Insights from the Findings

# %% [raw]
# Active Emplpoyees:1233
# Attrition Count:237
# Attrition Rate of employee:16.12%
# There are More Male employees than female employees(Male -882(17%),Female -588(14%))
# Attrition is high among age group 18 to 31,looks like they need more training to retain in the job.
# Attriion high in HR departmet compared to other educational field.
# More people are leaving the company after they get Promoted.
# Attrition rate is high among people having very low job satisfaction,worklife balance,Relationship satisfaction.
# We can retain the employee by conducting the suvery to the employees about their job experience in the company,their expectations towards company and make necessary actions.
